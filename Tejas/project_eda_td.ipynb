# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
path = os.path.join("..","WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# #### Dropped below columns because it's only has one value for all rows.

# %%
df.drop(columns=['EmployeeCount', 'Over18', 'StandardHours'], inplace=True)

# %%
dfColumns = []
for i in df.columns:
    dfColumns.append([i, df[i].nunique(), df[i].drop_duplicates().values])
pd.DataFrame(dfColumns, columns = ['Features', 'Unique Number', 'Values'])
# Out:
#                     Features  Unique Number  \
# 0                        Age             43
# 1                  Attrition              2
# 2             BusinessTravel              3
# 3                  DailyRate            886
# 4                 Department              3
# 5           DistanceFromHome             29
# 6                  Education              5
# 7             EducationField              6
# 8             EmployeeNumber           1470
# 9    EnvironmentSatisfaction              4
# 10                    Gender              2
# 11                HourlyRate             71
# 12            JobInvolvement              4
# 13                  JobLevel              5
# 14                   JobRole              9
# 15           JobSatisfaction              4
# 16             MaritalStatus              3
# 17             MonthlyIncome           1349
# 18               MonthlyRate           1427
# 19        NumCompaniesWorked             10
# ...

# %% [markdown]
# #### Number 1 is Yes, means employee moves out of company and number 0 is No, means stay.

# %%
df['Attrition'] = np.where(df['Attrition'] == 'Yes', 1, 0)

# %%
df['Attrition'].value_counts()/df.shape[0]*100
# Out:
# 0    83.877551
# 1    16.122449
# Name: Attrition, dtype: float64

# %%
dfCol = []
for i in df.columns:
    dfCol.append([i, df[i].nunique(), df[i].drop_duplicates().values])
pd.DataFrame(dfCol, columns = ['Columns', 'Unique Number', 'Values'])
# Out:
#                      Columns  Unique Number  \
# 0                        Age             43
# 1                  Attrition              2
# 2             BusinessTravel              3
# 3                  DailyRate            886
# 4                 Department              3
# 5           DistanceFromHome             29
# 6                  Education              5
# 7             EducationField              6
# 8             EmployeeNumber           1470
# 9    EnvironmentSatisfaction              4
# 10                    Gender              2
# 11                HourlyRate             71
# 12            JobInvolvement              4
# 13                  JobLevel              5
# 14                   JobRole              9
# 15           JobSatisfaction              4
# 16             MaritalStatus              3
# 17             MonthlyIncome           1349
# 18               MonthlyRate           1427
# 19        NumCompaniesWorked             10
# ...

# %%
# Correlation Plot
f, ax = plt.subplots(figsize=(20, 15))
corr = df.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f', linewidths=.05)
f.subplots_adjust(top=0.95)
t= f.suptitle('HR-Employee-Attrition - Correlation Heatmap', fontsize=16)

# %% [markdown]
# #### We can see from the correlation plot that Attrition does not have strong correlation with any other variables.
# #### We can also see from the correlation plot that only few variables have relativley strong correaltion.
# #### Job Level and Monthly Income has highet correlation of 0.95, which makes sense.
#
# #### Some other correlated varibles
# #### TotalWorkingYears and Monthly Income (0.78)
# #### Age and TotalWorkingYears (0.68)
# #### YearsAtComapny and YearsWithCurrManager (0.77)
# #### YearsInCurrentRole and YearsWithCurrManager (0.71)
# #### YearsInCurrentRole and YearsAtCompany (0.76)

# %%
sns.jointplot('Attrition','Age', data=df, alpha=0.8)

# %%
plt.figure(figsize=[11,7])
ax = sns.countplot(x="Age", hue="Attrition", data=df, palette="Set1")

# %%
fig = plt.figure(figsize=(10, 6))
(df[df['Attrition'] == 1]['Age']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['Age']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### At young age lot more employee seems to be moving out

# %%
plt.figure(figsize=[11,7])
ax = sns.countplot(x="JobLevel", hue="Attrition", data=df, palette="Set1")

# %%
fig = plt.figure(figsize=(10, 6))
(df[df['Attrition'] == 1]['JobLevel']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['JobLevel']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("JobLevel")
# Out:
# Text(0.5, 0, 'JobLevel')

# %% [markdown]
# #### Low job level has higher attrition rate

# %%
plt.figure(figsize=[11,7])
ax = sns.countplot(x="Department", hue="Attrition", data=df, palette="Set1")

# %%
fig = plt.figure(figsize=(10, 6))
(df[df['Attrition'] == 1]['Department']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['Department']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("Department")
# Out:
# Text(0.5, 0, 'Department')

# %%
print(df[df['Attrition'] == 1]['Department'].value_counts())
print(df[df['Attrition'] == 0]['Department'].value_counts())
print(df[df['Department'] == 'Research & Development'].count().unique())
print(df[df['Department'] == 'Sales'].count().unique())
print(df[df['Department'] == 'Human Resources'].count().unique())
print('Research & Development:',133/961,828/961)
print('Sales:',92/446,354/446)
print('Human Resources',12/63,51/63)
# Out:
# Research & Development    133
# Sales                      92
# Human Resources            12
# Name: Department, dtype: int64
# Research & Development    828
# Sales                     354
# Human Resources            51
# Name: Department, dtype: int64
# [961]
# [446]
# [63]
# Research & Development: 0.1383975026014568 0.8616024973985432
# Sales: 0.2062780269058296 0.7937219730941704
# Human Resources 0.19047619047619047 0.8095238095238095

# %% [markdown]
# #### Sales and Human Resources department have higher Attrition rate then Research & Development

# %%
plt.figure(figsize=[11,7])
ax = sns.countplot(x="Gender", hue="Attrition", data=df, palette="Set1")

# %%
print(df[df['Attrition'] == 1]['Gender'].value_counts())
print(df[df['Attrition'] == 0]['Gender'].value_counts())
print(df[df['Gender'] == 'Male'].count().unique())
print(df[df['Gender'] == 'Female'].count().unique())
print('Male:',150/882,732/882)
print('Female:',87/588,501/588)
# Out:
# Male      150
# Female     87
# Name: Gender, dtype: int64
# Male      732
# Female    501
# Name: Gender, dtype: int64
# [882]
# [588]
# Male: 0.17006802721088435 0.8299319727891157
# Female: 0.14795918367346939 0.8520408163265306

# %% [markdown]
# #### Male has higher attrition rate then female

# %%
fig = plt.figure(figsize=(10, 6))
(df[df['Attrition'] == 1]['MonthlyIncome']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['MonthlyIncome']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("MonthlyIncome")
# Out:
# Text(0.5, 0, 'MonthlyIncome')

# %% [markdown]
# #### Attrition is higher at lower Monthly Income (Salary)

# %%
fig = plt.figure(figsize=(10, 6))
(df[df['Attrition'] == 1]['YearsAtCompany']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['YearsAtCompany']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("YearsAtCompany")
# Out:
# Text(0.5, 0, 'YearsAtCompany')

# %%
ax = sns.boxplot(x="Attrition", y="JobSatisfaction", data=df)

# %%
fig = plt.figure(figsize=(18, 6))
(df[df['Attrition'] == 1]['JobRole']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['JobRole']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("JobRole")
# Out:
# Text(0.5, 0, 'JobRole')

# %% [markdown]
# #### Sales Representative and Lab Technicain have higher attrition rate

# %%
fig = plt.figure(figsize=(6, 6))
(df[df['Attrition'] == 1]['MaritalStatus']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['MaritalStatus']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("MaritalStatus")
# Out:
# Text(0.5, 0, 'MaritalStatus')

# %% [markdown]
# #### Employee who are single has higher attrition rate

# %%
fig = plt.figure(figsize=(10, 6))
(df[df['Attrition'] == 1]['BusinessTravel']).hist(bins=30, color='blue', linewidth=1.0,alpha=0.5, label = 'Attrition=1',
              xlabelsize=8, ylabelsize=8, grid=True)  
(df[df['Attrition'] == 0]['BusinessTravel']).hist(bins=30, color='red', linewidth=1.0,alpha=0.5,label = 'Attrition=0',
              xlabelsize=8, ylabelsize=8, grid=True)  
plt.legend()
plt.xlabel("BusinessTravel")
# Out:
# Text(0.5, 0, 'BusinessTravel')

# %% [markdown]
# #### Employee who Travel Frequently has higher attrition rate
